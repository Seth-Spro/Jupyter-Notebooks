# %% [markdown]
# ## HOMEWORK CHPTR3

# %%
import pandas as pd

# %%
ramen_url = 'C:\\Users\\Seith Sproule\\Documents\\UNI\\ramen-ratings.csv'
ramen_data = pd.read_csv(ramen_url)

# %% [markdown]
# ## Exercise 1

# %%
ramen_data
# Out:
#                Brand                                            Variety Style  \
# 0          New Touch                          T's Restaurant Tantanmen    Cup
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2             Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4     Ching's Secret                                    Singapore Curry  Pack
# ...              ...                                                ...   ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573         Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574         Wai Wai                                     Tom Yum Shrimp  Pack
# 2575         Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576        Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# ...

# %%
ramen_data.Stars.plot.hist(bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
ramen_data.Stars.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
avg_rating = ramen_data.groupby('Country').agg('mean')
avg_rating.plot.bar()
# Out:
# C:\Users\Seith Sproule\AppData\Local\Temp\ipykernel_11912\1405742304.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating = ramen_data.groupby('Country').agg('mean')
# <Axes: xlabel='Country'>

# %%
total_rating = ramen_data.groupby('Country').agg('count')
total_rating.Stars.plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %%
max_rating = ramen_data.groupby('Country').agg('max')
max_rating.Stars.plot.bar()
# Out:
# C:\Users\Seith Sproule\AppData\Local\Temp\ipykernel_11912\27931645.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   max_rating = ramen_data.groupby('Country').agg('max')
# <Axes: xlabel='Country'>

# %%
# the dataset has no resturants so I did a bar chart for variety and brand

# %%
variety = ramen_data.groupby('Country').agg('count')
variety.Variety.plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %%
style = ramen_data.groupby('Country').agg('count')
style.Style.plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ## Exercise 2

# %%
avo_url = 'C:\\Users\\Seith Sproule\\Documents\\UNI\\avocado.csv'
avo_data = pd.read_csv(avo_url)

# %%
bag_columns = ['Small Bags', 'Large Bags', 'XLarge Bags','type']
bags_df = avo_data[bag_columns]

# %%
bags_df.groupby('type').agg('sum').plot.bar()
# Out:
# <Axes: xlabel='type'>

# %%
avo_data.plot.scatter(x='Total Volume', y='AveragePrice')
# Out:
# <Axes: xlabel='Total Volume', ylabel='AveragePrice'>

# %%
avo_data.groupby('year').agg('sum')['Total Bags'].plot.bar()
# Out:
# C:\Users\Seith Sproule\AppData\Local\Temp\ipykernel_11912\3996444839.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avo_data.groupby('year').agg('sum')['Total Bags'].plot.bar()
# <Axes: xlabel='year'>

# %%
avo_data.plot.scatter(x='Total Bags', y='AveragePrice')
# Out:
# <Axes: xlabel='Total Bags', ylabel='AveragePrice'>

# %%
avo_data.groupby('year').AveragePrice.plot.bar()
